# %% [markdown]
# # Cursland
#
# ## Ejercicio de Integrales #10
#
# [Canal de Youtube](https://www.youtube.com/@Cursland)
#
# [Lista de Reproducción de Integrales](https://youtube.com/playlist?list=PLa4T14UYWeoUTyjTH_gSF90i5xhKd_wGI&feature=shared)

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math, Markdown

x = sp.symbols('x')

#
# ÁLGEBRA
#

y = 5 * sp.cos(3 * x**2)
integral = sp.integrate(y, x)
respuesta = (5 / 6) * sp.sin(3 * x**2)

# Comprobamos si la integral propuesta es correcta
es_correcta = sp.simplify(sp.diff(respuesta, x) - y) == 0

# Mostramos la función y la integral
display(Markdown("### La función es:"))
display(Math(sp.latex(y)))
print(f"La función en latex es: {sp.latex(y)}")

display(Markdown("### La integral es:"))
display(Math(sp.latex(integral)))
print(f"La integral en latex es: {sp.latex(integral)}")

mensaje = 'CORRECTA' if es_correcta else 'INCORRECTA'
display(Markdown(f"### La respuesta es: {mensaje}"))
display(Math(r"\boxed{\int 5 \cos(3x^2) \, dx = \frac{5}{6} \sin(3x^2) + C}"))
print(f"La respuesta en latex es: {sp.latex(respuesta)}")


#
# GRÁFICA
#

def graficar(f, intervalos, grafica, etiqueta, estilo, color):
    grafica.xlabel('$x$')
    grafica.ylabel('$y$')
    grafica.grid(True)

    for intervalo in intervalos:
        inicio = intervalo[0]
        fin = intervalo[1]
        
        x_vals = np.linspace(inicio, fin, 400)
            
        y_vals = [f(x_val) for x_val in x_vals]
        
        # Si es el primero, agregamos la etiqueta
        if intervalo == intervalos[0]:
            grafica.plot(x_vals, y_vals, label=etiqueta, linestyle=estilo, color=color) 
        else:
            grafica.plot(x_vals, y_vals, linestyle=estilo, color=color)

def funcion(x) -> float:
    return 5 * np.cos(3 * x**2)

def integral_func(x) -> float:
    return (5 / 6) * np.sin(3 * x**2)

plt.figure(figsize=(10, 6))
plt.title("Integral - Ejercicio 10")
plt.suptitle("Cursland")
plt.margins(0)

# Graficamos la función
graficar(funcion, [(-3, 3)], plt, "Función $f(x)$", "solid", "#2ecc71")
graficar(integral_func, [(-3, 3)], plt, "Integral $F(x)$", "--", "#2980b9")

# Personalización de la gráfica
plt.ylim(-6, 6)
plt.legend()

# Guardar la gráfica
plt.savefig("Ejercicio_10.svg", format='svg')
plt.savefig("Ejercicio_10.png", format='png', dpi=300)

plt.show()
# Out:
# ### La función es:
# $\displaystyle 5 \cos{\left(3 x^{2} \right)}$
# La función en latex es: 5 \cos{\left(3 x^{2} \right)}
# ### La integral es:
# $\displaystyle \frac{5 \sqrt{6} \sqrt{\pi} C\left(\frac{\sqrt{6} x}{\sqrt{\pi}}\right) \Gamma\left(\frac{1}{4}\right)}{24 \Gamma\left(\frac{5}{4}\right)}$
# La integral en latex es: \frac{5 \sqrt{6} \sqrt{\pi} C\left(\frac{\sqrt{6} x}{\sqrt{\pi}}\right) \Gamma\left(\frac{1}{4}\right)}{24 \Gamma\left(\frac{5}{4}\right)}
# ### La respuesta es: INCORRECTA
# $\displaystyle \boxed{\int 5 \cos(3x^2) \, dx = \frac{5}{6} \sin(3x^2) + C}$
# La respuesta en latex es: 0.833333333333333 \sin{\left(3 x^{2} \right)}
