# %% [markdown]
# # Cursland
#
# ## Ejercicio de Integrales #2
#
# [Canal de Youtube](https://www.youtube.com/@Cursland)
#
# [Lista de Reproducción de Integrales](https://youtube.com/playlist?list=PLa4T14UYWeoUTyjTH_gSF90i5xhKd_wGI&feature=shared)

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math, Markdown

x = sp.symbols('x')

#
# ÁLGEBRA
#

u = sp.exp(x)
dv = sp.cos(x)
v = sp.integrate(dv, x)
du = sp.diff(u, x)

integral = u * v - sp.integrate(v * du, x)
respuesta = sp.Rational(1, 2) * sp.exp(x) * (sp.cos(x) + sp.sin(x))

# Comprobamos si la integral propuesta es correcta
es_correcta = sp.simplify(sp.diff(respuesta, x) - (u * dv)) == 0

# Mostramos la función y la integral
display(Markdown("### La función es:"))
display(Math(r"\int e^x \cos(x) \, dx"))
print(r"La función en latex es: \int e^x \cos(x) \, dx")

display(Markdown("### La integral es:"))
display(Math(sp.latex(integral)))
print(f"La integral en latex es: {sp.latex(integral)}")

mensaje = 'CORRECTA' if es_correcta else 'INCORRECTA'
display(Markdown(f"### La respuesta es: {mensaje}"))
display(Math(sp.latex(respuesta)))
print(f"La respuesta en latex es: {sp.latex(respuesta)}")


#
# GRÁFICA
#

def graficar(f, intervalos, grafica, etiqueta, estilo, color):
    grafica.xlabel('$x$')
    grafica.ylabel('$y$')
    grafica.grid(True)

    for intervalo in intervalos:
        inicio = intervalo[0]
        fin = intervalo[1]
        
        x_vals = np.linspace(inicio, fin, 400)
            
        y_vals = [f(x_val) for x_val in x_vals]
        
        # Si es el primero, agregamos la etiqueta
        if intervalo == intervalos[0]:
            grafica.plot(x_vals, y_vals, label=etiqueta, linestyle=estilo, color=color) 
        else:
            grafica.plot(x_vals, y_vals, linestyle=estilo, color=color)

def potencia_fraccionaria(x, n, m):
    signo = np.sign(x)
    x = abs(x)
    x = x ** (1/m)
    x = x * signo
    return x ** n


def funcion(x) -> float:
    return np.exp(x) * np.cos(x)


def integral_func(x) -> float:
    return 0.5 * np.exp(x) * (np.cos(x) + np.sin(x))


plt.figure(figsize=(10, 6))
plt.title("Integral - Ejercicio 2")
plt.suptitle("Cursland")
plt.margins(0)

# Graficamos la función
graficar(funcion, [(-3, 3)], plt, "Función $f(x)$", "solid", "#2ecc71")
graficar(integral_func, [(-3, 3)], plt, "Integral $F(x)$", "--", "#2980b9")

# Personalización de la gráfica
plt.ylim(-6, 6)
plt.legend()

# Guardar la gráfica
plt.savefig("Ejercicio_2.svg", format='svg')
plt.savefig("Ejercicio_2.png", format='png', dpi=300)

plt.show()
# Out:
# ### La función es:
# $\displaystyle \int e^x \cos(x) \, dx$
# La función en latex es: \int e^x \cos(x) \, dx
# ### La integral es:
# $\displaystyle \frac{e^{x} \sin{\left(x \right)}}{2} + \frac{e^{x} \cos{\left(x \right)}}{2}$
# La integral en latex es: \frac{e^{x} \sin{\left(x \right)}}{2} + \frac{e^{x} \cos{\left(x \right)}}{2}
# ### La respuesta es: CORRECTA
# $\displaystyle \frac{\left(\sin{\left(x \right)} + \cos{\left(x \right)}\right) e^{x}}{2}$
# La respuesta en latex es: \frac{\left(\sin{\left(x \right)} + \cos{\left(x \right)}\right) e^{x}}{2}
