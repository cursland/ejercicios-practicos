# %% [markdown]
# # Cursland
#
# ## Ejercicio de Derivadas #42
#
# [Canal de Youtube](https://www.youtube.com/@Cursland)
#
# [Lista de Reproducción de Derivadas](https://youtube.com/playlist?list=PLa4T14UYWeoUW2eNMSSkLiq5c6ivgAxuq&feature=shared)

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math, Markdown


x = sp.symbols('x')

#
# ÁLGEBRA
#

y = sp.tan(3*x**2 + x)
dy_dx = sp.diff(y, x)
respuesta = sp.sec(3*x**2 + x)**2 * (6*x + 1)

# Comprobamos si la derivada propuesta es correcta
es_correcta = sp.simplify(dy_dx - respuesta) == 0

# Mostramos la función y la derivada
display(Markdown("### La función es:"))
display(Math(sp.latex(y)))
print(f"La función en latex es: {sp.latex(y)}")

display(Markdown("### La derivada es:"))
display(Math(sp.latex(dy_dx)))
print(f"La derivada en latex es: {sp.latex(dy_dx)}")

mensaje = 'CORRECTA' if es_correcta else 'INCORRECTA'
display(Markdown(f"### La respuesta es: {mensaje}"))
display(Math(sp.latex(respuesta)))
print(f"La respuesta en latex es: {sp.latex(respuesta)}")


#
# GRÁFICA
#

def graficar(f, intervalos, grafica, etiqueta, estilo, color):
    grafica.xlabel('$x$')
    grafica.ylabel('$y$')
    grafica.grid(True)

    for intervalo in intervalos:
        inicio = intervalo[0]
        fin = intervalo[1]
        
        x_vals = np.linspace(inicio, fin, 400)
            
        y_vals = [f(x_val) for x_val in x_vals]
        
        #Si es el primero, agregamos la etiqueta
        if intervalo == intervalos[0]:
            grafica.plot(x_vals, y_vals, label=etiqueta, linestyle=estilo, color=color) 
        else:
            grafica.plot(x_vals, y_vals, linestyle=estilo, color=color)

def funcion(x) -> float:
    return np.tan(3*x**2 + x)

def derivada(x) -> float:
    return (1 / np.cos(3*x**2 + x))**2 * (6*x + 1)

plt.figure(figsize=(10, 6))
plt.title("Derivada - Ejercicio 42")
plt.suptitle("Cursland")
plt.margins(0)

# Graficamos la función
graficar(funcion, [(-1.3, -0.94), (-0.9, 0.55), (0.58, 1.076),], plt, "Función $y$", "solid", "#2ecc71")
graficar(derivada, [(-1.3, -1.000001), (-0.99999, 1.1)], plt, "Derivada $\\frac{dy}{dx}$", "--", "#2980b9")

# Personalización de la gráfica
plt.ylim(-6, 6)
plt.legend()

# Guardar la gráfica
plt.savefig("Ejercicio_42.svg", format='svg')
plt.savefig("Ejercicio_42.png", format='png', dpi=300)

plt.show()
# Out:
# ### La función es:
# $\displaystyle \tan{\left(3 x^{2} + x \right)}$
# La función en latex es: \tan{\left(3 x^{2} + x \right)}
# ### La derivada es:
# $\displaystyle \left(6 x + 1\right) \left(\tan^{2}{\left(3 x^{2} + x \right)} + 1\right)$
# La derivada en latex es: \left(6 x + 1\right) \left(\tan^{2}{\left(3 x^{2} + x \right)} + 1\right)
# ### La respuesta es: CORRECTA
# $\displaystyle \left(6 x + 1\right) \sec^{2}{\left(3 x^{2} + x \right)}$
# La respuesta en latex es: \left(6 x + 1\right) \sec^{2}{\left(3 x^{2} + x \right)}
