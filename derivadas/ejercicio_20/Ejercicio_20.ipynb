# %% [markdown]
# # Cursland
#
# ## Ejercicio de Derivadas #20
#
# [Canal de Youtube](https://www.youtube.com/@Cursland)
#
# [Lista de Reproducción de Derivadas](https://youtube.com/playlist?list=PLa4T14UYWeoUW2eNMSSkLiq5c6ivgAxuq&feature=shared)

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math, Markdown


x = sp.symbols('x')

#
# ÁLGEBRA
#

y = (x**3 + 2*x) * sp.exp(x) * sp.ln(x)
dy_dx = sp.diff(y, x)
respuesta = sp.exp(x) * ((3*x**2 + 2) * sp.ln(x) + (x**3 + 2*x) * sp.ln(x) + (x**2 + 2))

# Comprobamos si la derivada propuesta es correcta
es_correcta = sp.simplify(dy_dx - respuesta) == 0

# Mostramos la función y la derivada
display(Markdown("### La función es:"))
display(Math(sp.latex(y)))
print(f"La función en latex es: {sp.latex(y)}")

display(Markdown("### La derivada es:"))
display(Math(sp.latex(dy_dx)))
print(f"La derivada en latex es: {sp.latex(dy_dx)}")

mensaje = 'CORRECTA' if es_correcta else 'INCORRECTA'
display(Markdown(f"### La respuesta es: {mensaje}"))
display(Math(sp.latex(respuesta)))
print(f"La respuesta en latex es: {sp.latex(respuesta)}")


#
# GRÁFICA
#

def graficar(f, intervalos, grafica, etiqueta, estilo, color):
    grafica.xlabel('$x$')
    grafica.ylabel('$y$')
    grafica.grid(True)

    for intervalo in intervalos:
        inicio = intervalo[0]
        fin = intervalo[1]
        
        x_vals = np.linspace(inicio, fin, 400)
            
        y_vals = [f(x_val) for x_val in x_vals]
        
        #Si es el primero, agregamos la etiqueta
        if intervalo == intervalos[0]:
            grafica.plot(x_vals, y_vals, label=etiqueta, linestyle=estilo, color=color) 
        else:
            grafica.plot(x_vals, y_vals, linestyle=estilo, color=color)

def funcion(x) -> float:
    numerador = (x**3 + 2*x) * np.exp(x) * np.log(x)
    return numerador

def derivada(x) -> float:
    a_numerador = (3*x**2 + 2) * np.log(x)
    b_numerador = (x**3 + 2*x) * np.log(x)
    c_numerador = x**2 + 2
    resultado = np.exp(x) * (a_numerador + b_numerador + c_numerador)
    return resultado

plt.figure(figsize=(10, 6))
plt.title("Derivada - Ejercicio 20")
plt.suptitle("Cursland")
plt.margins(0)

# Graficamos la función
graficar(funcion, [(0.001, 3)], plt, "Función $y$", "solid", "#2ecc71")
graficar(derivada, [(0.001, 3)], plt, "Derivada $\\frac{dy}{dx}$", "--", "#2980b9")

# Personalización de la gráfica
plt.ylim(-10, 10)
plt.legend()

# Guardar la gráfica
plt.savefig("Ejercicio_20.svg", format='svg')
plt.savefig("Ejercicio_20.png", format='png', dpi=300)

plt.show()
# Out:
# ### La función es:
# $\displaystyle \left(x^{3} + 2 x\right) e^{x} \log{\left(x \right)}$
# La función en latex es: \left(x^{3} + 2 x\right) e^{x} \log{\left(x \right)}
# ### La derivada es:
# $\displaystyle \left(3 x^{2} + 2\right) e^{x} \log{\left(x \right)} + \left(x^{3} + 2 x\right) e^{x} \log{\left(x \right)} + \frac{\left(x^{3} + 2 x\right) e^{x}}{x}$
# La derivada en latex es: \left(3 x^{2} + 2\right) e^{x} \log{\left(x \right)} + \left(x^{3} + 2 x\right) e^{x} \log{\left(x \right)} + \frac{\left(x^{3} + 2 x\right) e^{x}}{x}
# ### La respuesta es: CORRECTA
# $\displaystyle \left(x^{2} + \left(3 x^{2} + 2\right) \log{\left(x \right)} + \left(x^{3} + 2 x\right) \log{\left(x \right)} + 2\right) e^{x}$
# La respuesta en latex es: \left(x^{2} + \left(3 x^{2} + 2\right) \log{\left(x \right)} + \left(x^{3} + 2 x\right) \log{\left(x \right)} + 2\right) e^{x}
