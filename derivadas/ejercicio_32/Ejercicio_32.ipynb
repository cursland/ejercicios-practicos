# %% [markdown]
# # Cursland
#
# ## Ejercicio de Derivadas #32
#
# [Canal de Youtube](https://www.youtube.com/@Cursland)
#
# [Lista de Reproducción de Derivadas](https://youtube.com/playlist?list=PLa4T14UYWeoUW2eNMSSkLiq5c6ivgAxuq&feature=shared)

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math, Markdown


x = sp.symbols('x')

#
# ÁLGEBRA
#

y = x**2 * sp.sin(x) / (x**3 + 1)
dy_dx = sp.diff(y, x)
respuesta = (-x**4 * sp.sin(x) + 2 * x * sp.sin(x) + x**5 * sp.cos(x) + x**2 * sp.cos(x)) / (x**3 + 1)**2

# Comprobamos si la derivada propuesta es correcta
es_correcta = sp.simplify(dy_dx - respuesta) == 0

# Mostramos la función y la derivada
display(Markdown("### La función es:"))
display(Math(sp.latex(y)))
print(f"La función en latex es: {sp.latex(y)}")

display(Markdown("### La derivada es:"))
display(Math(sp.latex(dy_dx)))
print(f"La derivada en latex es: {sp.latex(dy_dx)}")

mensaje = 'CORRECTA' if es_correcta else 'INCORRECTA'
display(Markdown(f"### La respuesta es: {mensaje}"))
display(Math(sp.latex(respuesta)))
print(f"La respuesta en latex es: {sp.latex(respuesta)}")


#
# GRÁFICA
#

def graficar(f, intervalos, grafica, etiqueta, estilo, color):
    grafica.xlabel('$x$')
    grafica.ylabel('$y$')
    grafica.grid(True)

    for intervalo in intervalos:
        inicio = intervalo[0]
        fin = intervalo[1]
        
        x_vals = np.linspace(inicio, fin, 400)
            
        y_vals = [f(x_val) for x_val in x_vals]
        
        #Si es el primero, agregamos la etiqueta
        if intervalo == intervalos[0]:
            grafica.plot(x_vals, y_vals, label=etiqueta, linestyle=estilo, color=color) 
        else:
            grafica.plot(x_vals, y_vals, linestyle=estilo, color=color)

def funcion(x) -> float:
    numerador = x**2 * np.sin(x)
    denominador = x**3 + 1
    
    return numerador / denominador

def derivada(x) -> float:
    a_numerador = -x**4 * np.sin(x) + 2 * x * np.sin(x) + x**5 * np.cos(x) + x**2 * np.cos(x)
    a_denominador = (x**3 + 1) ** 2
    
    return a_numerador / a_denominador

plt.figure(figsize=(10, 6))
plt.title("Derivada - Ejercicio 32")
plt.suptitle("Cursland")
plt.margins(0)

# Graficamos la función
graficar(funcion, [(-3, -1.000001), (-0.99999, 3)], plt, "Función $y$", "solid", "#2ecc71")
graficar(derivada, [(-3, -1.000001), (-0.99999, 3)], plt, "Derivada $\\frac{dy}{dx}$", "--", "#2980b9")

# Personalización de la gráfica
plt.ylim(-6, 6)
plt.legend()

# Guardar la gráfica
plt.savefig("Ejercicio_32.svg", format='svg')
plt.savefig("Ejercicio_32.png", format='png', dpi=300)

plt.show()
# Out:
# ### La función es:
# $\displaystyle \frac{x^{2} \sin{\left(x \right)}}{x^{3} + 1}$
# La función en latex es: \frac{x^{2} \sin{\left(x \right)}}{x^{3} + 1}
# ### La derivada es:
# $\displaystyle - \frac{3 x^{4} \sin{\left(x \right)}}{\left(x^{3} + 1\right)^{2}} + \frac{x^{2} \cos{\left(x \right)}}{x^{3} + 1} + \frac{2 x \sin{\left(x \right)}}{x^{3} + 1}$
# La derivada en latex es: - \frac{3 x^{4} \sin{\left(x \right)}}{\left(x^{3} + 1\right)^{2}} + \frac{x^{2} \cos{\left(x \right)}}{x^{3} + 1} + \frac{2 x \sin{\left(x \right)}}{x^{3} + 1}
# ### La respuesta es: CORRECTA
# $\displaystyle \frac{x^{5} \cos{\left(x \right)} - x^{4} \sin{\left(x \right)} + x^{2} \cos{\left(x \right)} + 2 x \sin{\left(x \right)}}{\left(x^{3} + 1\right)^{2}}$
# La respuesta en latex es: \frac{x^{5} \cos{\left(x \right)} - x^{4} \sin{\left(x \right)} + x^{2} \cos{\left(x \right)} + 2 x \sin{\left(x \right)}}{\left(x^{3} + 1\right)^{2}}
