# %% [markdown]
# # Cursland
#
# ## Ejercicio de Derivadas #23
#
# [Canal de Youtube](https://www.youtube.com/@Cursland)
#
# [Lista de Reproducción de Derivadas](https://youtube.com/playlist?list=PLa4T14UYWeoUW2eNMSSkLiq5c6ivgAxuq&feature=shared)

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math, Markdown


x = sp.symbols('x')

#
# ÁLGEBRA
#

y = sp.tan(x)**2 * sp.ln(x**2)
dy_dx = sp.diff(y, x)
respuesta = 2 * sp.tan(x) * sp.sec(x)**2 * sp.ln(x**2) + (2 * sp.tan(x)**2) / x

# Comprobamos si la derivada propuesta es correcta
es_correcta = sp.simplify(dy_dx - respuesta) == 0

# Mostramos la función y la derivada
display(Markdown("### La función es:"))
display(Math(sp.latex(y)))
print(f"La función en latex es: {sp.latex(y)}")

display(Markdown("### La derivada es:"))
display(Math(sp.latex(dy_dx)))
print(f"La derivada en latex es: {sp.latex(dy_dx)}")

mensaje = 'CORRECTA' if es_correcta else 'INCORRECTA'
display(Markdown(f"### La respuesta es: {mensaje}"))
display(Math(sp.latex(respuesta)))
print(f"La respuesta en latex es: {sp.latex(respuesta)}")


#
# GRÁFICA
#

def graficar(f, intervalos, grafica, etiqueta, estilo, color):
    grafica.xlabel('$x$')
    grafica.ylabel('$y$')
    grafica.grid(True)

    for intervalo in intervalos:
        inicio = intervalo[0]
        fin = intervalo[1]
        
        x_vals = np.linspace(inicio, fin, 400)
            
        y_vals = [f(x_val) for x_val in x_vals]
        
        #Si es el primero, agregamos la etiqueta
        if intervalo == intervalos[0]:
            grafica.plot(x_vals, y_vals, label=etiqueta, linestyle=estilo, color=color) 
        else:
            grafica.plot(x_vals, y_vals, linestyle=estilo, color=color)

def funcion(x) -> float:
    numerador = np.tan(x)**2
    denominador = np.log(x**2)
    
    return numerador * denominador

def derivada(x) -> float:
    a_numerador = 2 * np.tan(x) * (1 / np.cos(x))**2 * np.log(x**2)
    b_numerador = 2 * np.tan(x)**2
    b_denominador = x
        
    return a_numerador + (b_numerador / b_denominador)

plt.figure(figsize=(10, 6))
plt.title("Derivada - Ejercicio 23")
plt.suptitle("Cursland")
plt.margins(0)

# Graficamos la función
graficar(funcion, [(-1.5, 1.5)], plt, "Función $y$", "solid", "#2ecc71")
graficar(derivada, [(-1.5, 1.5)], plt, "Derivada $\\frac{dy}{dx}$", "--", "#2980b9")

# Personalización de la gráfica
plt.ylim(-2, 2)
plt.legend()

# Guardar la gráfica
plt.savefig("Ejercicio_23.svg", format='svg')
plt.savefig("Ejercicio_23.png", format='png', dpi=300)

plt.show()
# Out:
# ### La función es:
# $\displaystyle \log{\left(x^{2} \right)} \tan^{2}{\left(x \right)}$
# La función en latex es: \log{\left(x^{2} \right)} \tan^{2}{\left(x \right)}
# ### La derivada es:
# $\displaystyle \left(2 \tan^{2}{\left(x \right)} + 2\right) \log{\left(x^{2} \right)} \tan{\left(x \right)} + \frac{2 \tan^{2}{\left(x \right)}}{x}$
# La derivada en latex es: \left(2 \tan^{2}{\left(x \right)} + 2\right) \log{\left(x^{2} \right)} \tan{\left(x \right)} + \frac{2 \tan^{2}{\left(x \right)}}{x}
# ### La respuesta es: CORRECTA
# $\displaystyle 2 \log{\left(x^{2} \right)} \tan{\left(x \right)} \sec^{2}{\left(x \right)} + \frac{2 \tan^{2}{\left(x \right)}}{x}$
# La respuesta en latex es: 2 \log{\left(x^{2} \right)} \tan{\left(x \right)} \sec^{2}{\left(x \right)} + \frac{2 \tan^{2}{\left(x \right)}}{x}
