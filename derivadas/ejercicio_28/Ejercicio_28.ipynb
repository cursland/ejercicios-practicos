# %% [markdown]
# # Cursland
#
# ## Ejercicio de Derivadas #28
#
# [Canal de Youtube](https://www.youtube.com/@Cursland)
#
# [Lista de Reproducción de Derivadas](https://youtube.com/playlist?list=PLa4T14UYWeoUW2eNMSSkLiq5c6ivgAxuq&feature=shared)

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math, Markdown

x = sp.symbols('x')

#
# ÁLGEBRA
#

y = (x**4 * sp.ln(x)) / (x**2 + 3)
dy_dx = sp.diff(y, x)
respuesta = (2 * x**5 * sp.ln(x) + x**5 + 12 * x**3 * sp.ln(x) + 3 * x**3) / (x**2 + 3)**2

# Comprobamos si la derivada propuesta es correcta
es_correcta = sp.simplify(dy_dx - respuesta) == 0

# Mostramos la función y la derivada
display(Markdown("### La función es:"))
display(Math(sp.latex(y)))
print(f"La función en latex es: {sp.latex(y)}")

display(Markdown("### La derivada es:"))
display(Math(sp.latex(dy_dx)))
print(f"La derivada en latex es: {sp.latex(dy_dx)}")

mensaje = 'CORRECTA' if es_correcta else 'INCORRECTA'
display(Markdown(f"### La respuesta es: {mensaje}"))
display(Math(sp.latex(respuesta)))
print(f"La respuesta en latex es: {sp.latex(respuesta)}")


#
# GRÁFICA
#

def graficar(f, intervalos, grafica, etiqueta, estilo, color):
    grafica.xlabel('$x$')
    grafica.ylabel('$y$')
    grafica.grid(True)

    for intervalo in intervalos:
        inicio = intervalo[0]
        fin = intervalo[1]
        
        x_vals = np.linspace(inicio, fin, 400)
            
        y_vals = [f(x_val) for x_val in x_vals]
        
        #Si es el primero, agregamos la etiqueta
        if intervalo == intervalos[0]:
            grafica.plot(x_vals, y_vals, label=etiqueta, linestyle=estilo, color=color) 
        else:
            grafica.plot(x_vals, y_vals, linestyle=estilo, color=color)

def potencia_fraccionaria(x, n, m):
    signo = np.sign(x)
    x = abs(x)
    x = x ** (1/m)
    x = x * signo
    return x ** n

def funcion(x) -> float:
    numerador = x**4 * np.log(x)
    denominador = x**2 + 3
    
    return numerador / denominador

def derivada(x) -> float:
    a_numerador = 2 * x**5 * np.log(x) + x**5
    b_numerador = 12 * x**3 * np.log(x) + 3 * x**3
    denominador = (x**2 + 3)**2
    
    return (a_numerador + b_numerador) / denominador

plt.figure(figsize=(10, 6))
plt.title("Derivada - Ejercicio 28")
plt.suptitle("Cursland")
plt.margins(0)

# Graficamos la función
graficar(funcion, [(0.1, 3)], plt, "Función $y$", "solid", "#2ecc71")
graficar(derivada, [(0.1, 3)], plt, "Derivada $\\frac{dy}{dx}$", "--", "#2980b9")

# Personalización de la gráfica
plt.ylim(-6, 6)
plt.legend()

# Guardar la gráfica
plt.savefig("Ejercicio_28.svg", format='svg')
plt.savefig("Ejercicio_28.png", format='png', dpi=300)

plt.show()
# Out:
# ### La función es:
# $\displaystyle \frac{x^{4} \log{\left(x \right)}}{x^{2} + 3}$
# La función en latex es: \frac{x^{4} \log{\left(x \right)}}{x^{2} + 3}
# ### La derivada es:
# $\displaystyle - \frac{2 x^{5} \log{\left(x \right)}}{\left(x^{2} + 3\right)^{2}} + \frac{4 x^{3} \log{\left(x \right)}}{x^{2} + 3} + \frac{x^{3}}{x^{2} + 3}$
# La derivada en latex es: - \frac{2 x^{5} \log{\left(x \right)}}{\left(x^{2} + 3\right)^{2}} + \frac{4 x^{3} \log{\left(x \right)}}{x^{2} + 3} + \frac{x^{3}}{x^{2} + 3}
# ### La respuesta es: CORRECTA
# $\displaystyle \frac{2 x^{5} \log{\left(x \right)} + x^{5} + 12 x^{3} \log{\left(x \right)} + 3 x^{3}}{\left(x^{2} + 3\right)^{2}}$
# La respuesta en latex es: \frac{2 x^{5} \log{\left(x \right)} + x^{5} + 12 x^{3} \log{\left(x \right)} + 3 x^{3}}{\left(x^{2} + 3\right)^{2}}
