# %% [markdown]
# # Cursland
#
# ## Ejercicio de Derivadas #33
#
# [Canal de Youtube](https://www.youtube.com/@Cursland)
#
# [Lista de Reproducción de Derivadas](https://youtube.com/playlist?list=PLa4T14UYWeoUW2eNMSSkLiq5c6ivgAxuq&feature=shared)

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math, Markdown


x = sp.symbols('x')

#
# ÁLGEBRA
#

y = sp.sqrt(x**3 + x) / (x**2 + 1)
dy_dx = sp.diff(y, x)
respuesta = ((3*x**2 + 1)*(x**2 + 1)/(2*sp.sqrt(x**3 + x)) - 2*x*sp.sqrt(x**3 + x)) / (x**2 + 1)**2

# Comprobamos si la derivada propuesta es correcta
es_correcta = sp.simplify(dy_dx - respuesta) == 0

# Mostramos la función y la derivada
display(Markdown("### La función es:"))
display(Math(sp.latex(y)))
print(f"La función en latex es: {sp.latex(y)}")

display(Markdown("### La derivada es:"))
display(Math(sp.latex(dy_dx)))
print(f"La derivada en latex es: {sp.latex(dy_dx)}")

mensaje = 'CORRECTA' if es_correcta else 'INCORRECTA'
display(Markdown(f"### La respuesta es: {mensaje}"))
display(Math(sp.latex(respuesta)))
print(f"La respuesta en latex es: {sp.latex(respuesta)}")


#
# GRÁFICA
#

def graficar(f, intervalos, grafica, etiqueta, estilo, color):
    grafica.xlabel('$x$')
    grafica.ylabel('$y$')
    grafica.grid(True)

    for intervalo in intervalos:
        inicio = intervalo[0]
        fin = intervalo[1]
        
        x_vals = np.linspace(inicio, fin, 400)
            
        y_vals = [f(x_val) for x_val in x_vals]
        
        #Si es el primero, agregamos la etiqueta
        if intervalo == intervalos[0]:
            grafica.plot(x_vals, y_vals, label=etiqueta, linestyle=estilo, color=color) 
        else:
            grafica.plot(x_vals, y_vals, linestyle=estilo, color=color)

def potencia_fraccionaria(x, n, m):
    signo = np.sign(x)
    x = abs(x)
    x = x ** (1/m)
    x = x * signo
    return x ** n

def funcion(x) -> float:
    numerador = (x**3 + x)**(1/2)
    denominador = x**2 + 1
    
    return numerador / denominador

def derivada(x) -> float:
    a_numerador = -2 * x * (x**3 + x)**(1/2)
    b_numerador = (x ** 2 + 1) * (3 * x ** 2 + 1) / (2 * (x**3 + x)**(1/2))
    denominador = (x**2 + 1)**2
        
    return (a_numerador + b_numerador) / denominador

plt.figure(figsize=(10, 6))
plt.title("Derivada - Ejercicio 33")
plt.suptitle("Cursland")
plt.margins(0)

# Graficamos la función
graficar(funcion, [(0.000001, 3)], plt, "Función $y$", "solid", "#2ecc71")
graficar(derivada, [(0.000001, 3)], plt, "Derivada $\\frac{dy}{dx}$", "--", "#2980b9")

# Personalización de la gráfica
plt.ylim(-0.25, 2)
plt.legend()

# Guardar la gráfica
plt.savefig("Ejercicio_33.svg", format='svg')
plt.savefig("Ejercicio_33.png", format='png', dpi=300)

plt.show()
# Out:
# ### La función es:
# $\displaystyle \frac{\sqrt{x^{3} + x}}{x^{2} + 1}$
# La función en latex es: \frac{\sqrt{x^{3} + x}}{x^{2} + 1}
# ### La derivada es:
# $\displaystyle - \frac{2 x \sqrt{x^{3} + x}}{\left(x^{2} + 1\right)^{2}} + \frac{\frac{3 x^{2}}{2} + \frac{1}{2}}{\left(x^{2} + 1\right) \sqrt{x^{3} + x}}$
# La derivada en latex es: - \frac{2 x \sqrt{x^{3} + x}}{\left(x^{2} + 1\right)^{2}} + \frac{\frac{3 x^{2}}{2} + \frac{1}{2}}{\left(x^{2} + 1\right) \sqrt{x^{3} + x}}
# ### La respuesta es: CORRECTA
# $\displaystyle \frac{- 2 x \sqrt{x^{3} + x} + \frac{\left(x^{2} + 1\right) \left(3 x^{2} + 1\right)}{2 \sqrt{x^{3} + x}}}{\left(x^{2} + 1\right)^{2}}$
# La respuesta en latex es: \frac{- 2 x \sqrt{x^{3} + x} + \frac{\left(x^{2} + 1\right) \left(3 x^{2} + 1\right)}{2 \sqrt{x^{3} + x}}}{\left(x^{2} + 1\right)^{2}}
